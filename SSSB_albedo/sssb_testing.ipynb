# %%
import sssb_albedo as sb
import matplotlib.pyplot as plt
# Out:
# /usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tqdm/autonotebook/__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %%
mba2 = sb.sssb(source='MBA smooth',time=0,frame='Ecliptic',pixelsize=3.0)

# %%
mba2.image.shape
# Out:
# (60, 120)

# %%
mba2.plot_source()

# %%
mba2.trafo_image_EC2GAL()
# Out:
# Changing frame to: Galactic

# %%
mba2.plot_source(projection='aitoff')

# %%
mba2.trafo_image_GAL2EC()
# Out:
# Changing frame to: Ecliptic

# %%
mba2.plot_source(projection='aitoff')

# %%
mba = sb.sssb(source='MBA solid',time=0,frame='Ecliptic',pixelsize=3)

# %%
mba.plot_source()

# %%
mba.trafo_image_EC2GAL()
# Out:
# Changing frame to: Galactic

# %%
mba.plot_source()

# %%
mba.trafo_image_GAL2EC()
# Out:
# Changing frame to: Ecliptic

# %%
mba.plot_source()

# %%
kpo = sb.sssb(source='Kuiper Belt solid',time=0,frame='Ecliptic')

# %%
kpo.image

# %%
kpo = sb.sssb(source='Oort Cloud',time=0,frame='Ecliptic')
# Out:
# Source Oort Cloud not yet implemented.
